# %% [markdown]
# <h1> TITANIC </h1> </center>

# %%
#📚 Librerias básicas de visualización y de operaciones matemáticas
import pandas as pd
import numpy as np

#📋 Visualización
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# <h2> IMPORTACIÓN DE DATOS</h2> </center>

# %%
data1 = pd.read_csv('mascotas.csv')
data2 = pd.read_csv('pasa2.csv')
data3 = pd.read_csv('crew2.csv')

# %%
mas = data1.copy()
pasa = data2.copy()
crew = data3.copy()

# %% [markdown]
# <h2> ANÁLISIS DE DATOS CREW</h2> </center>
#
# -Las características de la tripulación:
#
#     ·Reparto según cargos y sin tipo.
#
#     ·Edades según oficio
#
#     ·Saber el porcentaje de supervivencia dentro de la tripulación

# %%
crew.set_index('crew_id', inplace = True)

# %%
crew['Crew_Type'].value_counts().sum()
# Out:
# 744

# %% [markdown]
# ·Saber el porcentaje de supervivencia dentro de la tripulación
#
# ![download.png](attachment:35a1a8bb-03b5-4c17-b0ea-e776a5858717.png)

# %%
#para crear un nuevo CSV
crew.to_csv('crew.csv')

# %% [markdown]
# <h2> ANÁLISIS DE DATOS MASCOTAS</h2> </center>
#
# ![mas.supervivencia.png](attachment:eecac410-2bed-4fa5-8bac-2697234f2836.png)

# %% [markdown]
# <h2> ANÁLISIS DE PASAJEROS</h2> </center>

# %%
pasa.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   714.000000  714.000000  714.000000  714.000000  714.000000
# mean    448.582633    0.406162    2.236695   29.712885    0.512605
# std     259.119524    0.491460    0.838250   14.529273    0.929783
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.250000    0.000000    1.000000   20.250000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %%
crew['Embarked'].value_counts()
# Out:
# Embarked
# Southampton    573
# Belfast        163
# Name: count, dtype: int64

# %%
def determinar_genero(row):
    if 'Miss' in row['Name'] or 'Mrs' in row['Name']:
        return 'female'
    else:
        return 'male'

# Aplicar la función a cada fila y crear la nueva columna
crew['Gender'] = crew.apply(determinar_genero, axis=1)
crew['Gender'].value_counts()
# Out:
# Gender
# male      721
# female     23
# Name: count, dtype: int64

# %%
data3['Embarked'] = data3['Embarked'].replace('Belfast, Ireland', 'Belfast')
data3['Embarked'] = data3['Embarked'].replace('Ireland', 'Belfast')

# %%
data3
# Out:
#      crew_id                                             Name  Age  \
# 0          0         Smith, Commander Edward John, RNR (Retd)   62
# 1          1                   Wilde, Lieutenant Henry Tingle   39
# 2          2        Murdoch, Lieutenant William McMaster, RNR   39
# 3          3  Lightoller, Sub-Lieutenant Charles Herbert, RNR   38
# 4          4                         Pitman, Mr. Herbert John   34
# ..       ...                                              ...  ...
# 739        3                       Hartley, Mr. Wallace Henry   33
# 740        4                      Hume, Mr. John Law Jock""""   21
# 741        5                     Krins, Mr. Georges Alexandre   23
# 742        6                     Taylor, Mr. Percy Cornelius    32
# 743        7                       Woodward, Mr. John Wesley    32
#
#         Embarked        Position Crew_Type  Survived  sección_id Gender
# 0    Southampton         Captain   Officer       NaN         NaN   male
# ...

# %%
pasa
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# ...                                                        ...     ...  ...
# ...
